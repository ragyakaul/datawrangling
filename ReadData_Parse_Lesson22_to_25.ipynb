# %% [markdown]
# ### Lesson 22: Reading Data Intro

# %%
# Reading CSV and TXT files
import pandas as pd

# %%
# Reading data with Python
with open('btc-market-price.csv', 'r') as fp: # file pointer
    print(fp)
# Out:
# <_io.TextIOWrapper name='btc-market-price.csv' mode='r' encoding='UTF-8'>

# %%
with open('btc-market-price.csv', 'r') as fp: 
    for index, line in enumerate(fp.readlines()):
        # read just the first 10 lines
        if (index < 10):
            print(index, line)
# Out:
# 0 2017-04-02 00:00:00,1099.169125
#
# 1 2017-04-03 00:00:00,1141.813
#
# 2 2017-04-04 00:00:00,1141.6003625
#
# 3 2017-04-05 00:00:00,1133.0793142857142
#
# 4 2017-04-06 00:00:00,1196.3079375
#
# 5 2017-04-07 00:00:00,1190.45425
#
# 6 2017-04-08 00:00:00,1181.1498375
#
# 7 2017-04-09 00:00:00,1208.8005
#
# 8 2017-04-10 00:00:00,1207.744875
#
# 9 2017-04-11 00:00:00,1226.6170375

# %%
with open('btc-market-price.csv', 'r') as fp:
    for index, line in enumerate(fp.readlines()):
        if (index < 10):
            timestamp, print = line.split(',')
            print(f"{timestamp}: ${price}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-b78978468c7c> in <module>
#       3         if (index < 10):
#       4             timestamp, print = line.split(',')
# ----> 5             print(f"{timestamp}: ${price}")
#
# NameError: name 'price' is not defined

# %% [markdown]
# ### Lesson 23: Reading Data CSV and TXT

# %%
# Find CSV file thru a link
csv_url =  'https://raw.githubusercontent.com/datasets/gdp/master/data/gdp.csv'

# %%
pd.read_csv(csv_url).head()
# Out:
#   Country Name Country Code  Year         Value
# 0   Arab World          ARB  1968  2.576068e+10
# 1   Arab World          ARB  1969  2.843420e+10
# 2   Arab World          ARB  1970  3.138550e+10
# 3   Arab World          ARB  1971  3.642691e+10
# 4   Arab World          ARB  1972  4.331606e+10

# %%
df = pd.read_csv('btc-market-price.csv')

df.head()
# Out:
#    2017-04-02 00:00:00  1099.169125
# 0  2017-04-03 00:00:00  1141.813000
# 1  2017-04-04 00:00:00  1141.600363
# 2  2017-04-05 00:00:00  1133.079314
# 3  2017-04-06 00:00:00  1196.307937
# 4  2017-04-07 00:00:00  1190.454250

# %%
 df = pd.read_csv('btc-market-price.csv',
                 header=None)

# %%
df.head()
# Out:
#                      0            1
# 0  2017-04-02 00:00:00  1099.169125
# 1  2017-04-03 00:00:00  1141.813000
# 2  2017-04-04 00:00:00  1141.600363
# 3  2017-04-05 00:00:00  1133.079314
# 4  2017-04-06 00:00:00  1196.307937

# %%
# Missing values 
df = pd.read_csv('btc-market-price.csv',
                header=None,
                na_values=['','?','-'])

# %%
df.head()
# Out:
#                      0            1
# 0  2017-04-02 00:00:00  1099.169125
# 1  2017-04-03 00:00:00  1141.813000
# 2  2017-04-04 00:00:00  1141.600363
# 3  2017-04-05 00:00:00  1133.079314
# 4  2017-04-06 00:00:00  1196.307937

# %%
df.tail()
# Out:
#                        0            1
# 360  2018-03-28 00:00:00  7960.380000
# 361  2018-03-29 00:00:00  7172.280000
# 362  2018-03-30 00:00:00  6882.531667
# 363  2018-03-31 00:00:00  6935.480000
# 364  2018-04-01 00:00:00  6794.105000

# %%
df = pd.read_csv('btc-market-price.csv',
                header=None,
                na_values=['','?','-'],
                names=['Timestamp', 'Price'])

# %%
df.head()
# Out:
#              Timestamp        Price
# 0  2017-04-02 00:00:00  1099.169125
# 1  2017-04-03 00:00:00  1141.813000
# 2  2017-04-04 00:00:00  1141.600363
# 3  2017-04-05 00:00:00  1133.079314
# 4  2017-04-06 00:00:00  1196.307937

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Timestamp  365 non-null    object
#  1   Price      365 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 5.8+ KB

# %%
df.dtypes
# Out:
# Timestamp     object
# Price        float64
# dtype: object

# %%
pd.to_datetime(df['Timestamp']).head()
# Out:
# 0   2017-04-02
# 1   2017-04-03
# 2   2017-04-04
# 3   2017-04-05
# 4   2017-04-06
# Name: Timestamp, dtype: datetime64[ns]

# %%
cat exam_review.csv #Cant find file
# Out:
# cat: exam_review.csv: No such file or directory

# %%
exam_df = pd.read_csv('exam_review.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-43cf182197cf> in <module>
# ----> 1 exam_df = pd.read_csv('exam_review.csv')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# ...

# %%
exam_df = pd.read_csv('exam_review.csv')

# %%
 exam_df.to_csv() # Process of writing

# %%
exam_df.to_csv('out.csv')

# %%
pd.read_csv('out.csv')

# %%
exam_df.to_csv('out.csv', index=None)

# %%
pd.read_csv('out.csv')

# %% [markdown]
# ### Lesson 24: Reading Data from Databases

# %%
import sqlite3

# %%
# Reading data using Python rather than pandas. What predates pandas

# %%
conn = sqlite3.connect('chinook.db')

# %%
cur = conn.cursor() # cursor created, execute queries using cursor

# %%
cat chinook.db

# %%
cur.execute('SELECT * FROM employees LIMIT 5;')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-32-905779b3af77> in <module>
# ----> 1 cur.execute('SELECT * FROM employees LIMIT 5;')
#
# OperationalError: no such table: employees

# %%
results = cur.fetchall() # fetch all the results of the query

# %%
results
# Out:
# []

# %%
df = pd.DataFrame(results)

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
cur.close()

# %%
conn.close() # Closed cursor and connected

# %%
# Using pandas read_sql method

# %%
conn = sqlite3.connect('chinook.db')

# %%
df = pd.read_sql('SELECT * FROM employees;', conn)

# %%
df = pd.read_sql('SELECT * FROM employees;', conn) # query, conn

# %%
df = pd.read_sql('SELECT * FROM employees;', conn,
                  index_col='EmployeeId',
                  parse_dates=['BirthDate', 'HireDate'])

# %%
pd.read_sql_query('SELECT * FROM employees;', conn)

# %%
pd.read_sql_table('employees', con = connection)

# %%
connection.close()

# %%
df.to_sql # Write

# %%
# if exists.... change to replace or append if you want to write

# %%
# Reading HTML tables

# %%
# !pip install lxml

# %%
# Parsing raw HTML strings

# %%
# html_string populated

# %%
pd.read_html(html_string) # parses the entire html

# %% [markdown]
# ### Lesson 25: Parsing HTML and Saving Data

# %%
html_url = "https://www.basketball-reference.com/leagues/NBA_2019_per_game.html"

# %%
nba_tables = pd.read_html(html_url)

# %%
len(html_url)
# Out:
# 67

# %%
len(nba_tables)
# Out:
# 1

# %%
nba = nba_tables[0]

# %%
nba.head()
# Out:
#   Rk        Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  ORB  DRB  \
# 0  1  Álex Abrines  SG  25  OKC  31   2  19.0  1.8   5.1  ...  .923  0.2  1.4
# 1  2    Quincy Acy  PF  28  PHO  10   0  12.3  0.4   1.8  ...  .700  0.3  2.2
# 2  3  Jaylen Adams  PG  22  ATL  34   1  12.6  1.1   3.2  ...  .778  0.3  1.4
# 3  4  Steven Adams   C  25  OKC  80  80  33.4  6.0  10.1  ...  .500  4.9  4.6
# 4  5   Bam Adebayo   C  21  MIA  82  28  23.3  3.4   5.9  ...  .735  2.0  5.3
#
#    TRB  AST  STL  BLK  TOV   PF   PTS
# 0  1.5  0.6  0.5  0.2  0.5  1.7   5.3
# 1  2.5  0.8  0.1  0.4  0.4  2.4   1.7
# 2  1.8  1.9  0.4  0.1  0.8  1.3   3.2
# 3  9.5  1.6  1.5  1.0  1.7  2.6  13.9
# 4  7.3  2.2  0.9  0.8  1.5  2.5   8.9
#
# [5 rows x 30 columns]

# %%
nba.head(25)
# Out:
#     Rk                  Player  Pos  Age   Tm   G  GS    MP    FG   FGA  ...  \
# 0    1            Álex Abrines   SG   25  OKC  31   2  19.0   1.8   5.1  ...
# 1    2              Quincy Acy   PF   28  PHO  10   0  12.3   0.4   1.8  ...
# 2    3            Jaylen Adams   PG   22  ATL  34   1  12.6   1.1   3.2  ...
# 3    4            Steven Adams    C   25  OKC  80  80  33.4   6.0  10.1  ...
# 4    5             Bam Adebayo    C   21  MIA  82  28  23.3   3.4   5.9  ...
# 5    6               Deng Adel   SF   21  CLE  19   3  10.2   0.6   1.9  ...
# 6    7  DeVaughn Akoon-Purcell   SG   25  DEN   7   0   3.1   0.4   1.4  ...
# 7    8       LaMarcus Aldridge    C   33  SAS  81  81  33.2   8.4  16.3  ...
# 8    9            Rawle Alkins   SG   21  CHI  10   1  12.0   1.3   3.9  ...
# 9   10           Grayson Allen   SG   23  UTA  38   2  10.9   1.8   4.7  ...
# 10  11           Jarrett Allen    C   20  BRK  80  80  26.2   4.2   7.1  ...
# ...

# %%
nba.drop(range(22,df.shape[0] + 1, 20))
# Out:
#       Rk        Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  ORB  \
# 0      1  Álex Abrines  SG  25  OKC  31   2  19.0  1.8   5.1  ...  .923  0.2
# 1      2    Quincy Acy  PF  28  PHO  10   0  12.3  0.4   1.8  ...  .700  0.3
# 2      3  Jaylen Adams  PG  22  ATL  34   1  12.6  1.1   3.2  ...  .778  0.3
# 3      4  Steven Adams   C  25  OKC  80  80  33.4  6.0  10.1  ...  .500  4.9
# 4      5   Bam Adebayo   C  21  MIA  82  28  23.3  3.4   5.9  ...  .735  2.0
# ..   ...           ...  ..  ..  ...  ..  ..   ...  ...   ...  ...   ...  ...
# 729  528  Tyler Zeller   C  29  MEM   4   1  20.5  4.0   7.0  ...  .778  2.3
# 730  529    Ante Žižić   C  22  CLE  59  25  18.3  3.1   5.6  ...  .705  1.8
# 731  530   Ivica Zubac   C  21  TOT  59  37  17.6  3.6   6.4  ...  .802  1.9
# 732  530   Ivica Zubac   C  21  LAL  33  12  15.6  3.4   5.8  ...  .864  1.6
# 733  530   Ivica Zubac   C  21  LAC  26  25  20.2  3.8   7.2  ...  .733  2.3
#
#      DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %%
import requests

html_url = "https://en.wikipedia.org/wiki/The_Simpsons"

# %%
r = requests.get(html_url)

wiki_tables = pd.read_html(r.text, header=0)

# %%
len(wiki_tables)
# Out:
# 31

# %%
simpsons = wiki_tables[1]

# %%
simpsons.head()
# Out:
#    Season Season.1  No. ofepisodes    Originally aired Originally aired.1  \
# 0  Season   Season  No. ofepisodes     Season premiere      Season finale
# 1  Season   Season  No. ofepisodes     Season premiere      Season finale
# 2       1  1989–90              13   December 17, 1989       May 13, 1990
# 3       2  1990–91              22    October 11, 1990      July 11, 1991
# 4       3  1991–92              24  September 19, 1991    August 27, 1992
#
#   Originally aired.2                 Viewership          Viewership.1  \
# 0     Time slot (ET)  Avg. viewers(in millions)  Most watched episode
# 1     Time slot (ET)  Avg. viewers(in millions)     Viewers(millions)
# 2     Sunday 8:30 pm                       27.8                  33.5
# 3   Thursday 8:00 pm                       24.4                  33.6
# 4   Thursday 8:00 pm                       21.8                  25.5
#
#               Viewership.2
# 0     Most watched episode
# 1            Episode title
# ...

# %%
# Can also write data to

# %%
# Reading Excel files

# %%
df = pd.read_excel('Products.xlsx')

# %%
df.head()
# Out:
#    ProductID                   ProductName  SupplierID  CategoryID  \
# 0          1                         Chais           1           1
# 1          2                         Chang           1           1
# 2          3                 Aniseed Syrup           1           2
# 3          4  Chef Anton's Cajun Seasoning           2           2
# 4          5        Chef Anton's Gumbo Mix           2           2
#
#                   Unit  Price
# 0   10 boxes x 20 bags  18.00
# 1   24 - 12 oz bottles  19.00
# 2  12 - 550 ml bottles  10.00
# 3       48 - 6 oz jars  22.00
# 4             36 boxes  21.35

# %%
pd.read_excel

# %%
# Selecting specific sheets
products = pd.read_excel('products.xlsx',
                        sheet_name='Products',
                        index_col='product_id')

# %%
excel_file = pd.ExcelFile('products.xlsx')

# %%
excel_file

# %%
excel_file.sheet_names # diff sheet names
# Out:
# ['Products']

# %%
products = excel_file.parse('Products')

# %%
products.head()
# Out:
#    ProductID                   ProductName  SupplierID  CategoryID  \
# 0          1                         Chais           1           1
# 1          2                         Chang           1           1
# 2          3                 Aniseed Syrup           1           2
# 3          4  Chef Anton's Cajun Seasoning           2           2
# 4          5        Chef Anton's Gumbo Mix           2           2
#
#                   Unit  Price
# 0   10 boxes x 20 bags  18.00
# 1   24 - 12 oz bottles  19.00
# 2  12 - 550 ml bottles  10.00
# 3       48 - 6 oz jars  22.00
# 4             36 boxes  21.35

# %%
products.to_excel('out.xlsx')

# %%
ExcelWriter!!

# %%
pd.read_ex
